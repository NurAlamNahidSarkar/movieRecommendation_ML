# %% [markdown]
# <a href="https://www.kaggle.com/code/nahidsarkar/movierecommendation?scriptVersionId=276255260" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/the-movies-dataset/ratings.csv
# /kaggle/input/the-movies-dataset/links_small.csv
# /kaggle/input/the-movies-dataset/credits.csv
# /kaggle/input/the-movies-dataset/keywords.csv
# /kaggle/input/the-movies-dataset/movies_metadata.csv
# /kaggle/input/the-movies-dataset/ratings_small.csv
# /kaggle/input/the-movies-dataset/links.csv

# %%
credits = pd.read_csv("/kaggle/input/the-movies-dataset/credits.csv")
keywords = pd.read_csv("/kaggle/input/the-movies-dataset/keywords.csv")
links = pd.read_csv("/kaggle/input/the-movies-dataset/links.csv")
links_small = pd.read_csv("/kaggle/input/the-movies-dataset/links_small.csv")
movies_metadata = pd.read_csv("/kaggle/input/the-movies-dataset/movies_metadata.csv")
ratings = pd.read_csv("/kaggle/input/the-movies-dataset/ratings.csv")
ratings_small = pd.read_csv("/kaggle/input/the-movies-dataset/ratings_small.csv")
# Out:
# /tmp/ipykernel_128/1146000887.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata = pd.read_csv("/kaggle/input/the-movies-dataset/movies_metadata.csv")

# %%
print(credits.columns)
print(keywords.columns)
print(links.columns)
print(links_small.columns)
print(movies_metadata.columns)
print(ratings.columns)
print(ratings_small.columns)
# Out:
# Index(['cast', 'crew', 'id'], dtype='object')
# Index(['id', 'keywords'], dtype='object')
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
credits.info()
keywords.info()
links.info()
links_small.info()
movies_metadata.info()
ratings.info()
ratings_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46419 entries, 0 to 46418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46419 non-null  int64
#  1   keywords  46419 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 725.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45843 entries, 0 to 45842
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  45843 non-null  int64
#  1   imdbId   45843 non-null  int64
#  2   tmdbId   45624 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.0 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9125 entries, 0 to 9124
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9125 non-null   int64
#  1   imdbId   9125 non-null   int64
#  2   tmdbId   9112 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 214.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
print("--- Checking for 100% Identical Rows ---")

print(f"credits: {credits.duplicated().sum()}")
print(f"keywords: {keywords.duplicated().sum()}")
print(f"ratings: {ratings.duplicated().sum()}")
print(f"ratings_small: {ratings_small.duplicated().sum()}")
print(f"links: {links.duplicated().sum()}")
print(f"links_small: {links_small.duplicated().sum()}")
print(f"movies_metadata: {movies_metadata.duplicated().sum()}")
# Out:
# --- Checking for 100% Identical Rows ---
# credits: 37
# keywords: 987
# ratings: 0
# ratings_small: 0
# links: 0
# links_small: 0
# movies_metadata: 13

# %%
print("\n--- Checking for Duplicate Keys ---")

print(f"movies_metadata 'id' duplicates: {movies_metadata.duplicated(subset=['id']).sum()}")

print(f"links 'movieId' duplicates: {links.duplicated(subset=['movieId']).sum()}")
print(f"links 'tmdbId' duplicates: {links.duplicated(subset=['tmdbId']).sum()}")
print(f"links_small 'movieId' duplicates: {links_small.duplicated(subset=['movieId']).sum()}")
print(f"links_small 'tmdbId' duplicates: {links_small.duplicated(subset=['tmdbId']).sum()}")

print(f"ratings duplicates: {ratings.duplicated(subset=['userId', 'movieId']).sum()}")
print(f"ratings_small duplicates: {ratings_small.duplicated(subset=['userId', 'movieId']).sum()}")

print(f"credits duplicates: {credits.duplicated(subset=['id']).sum()}")
print(f"keywords duplicates: {keywords.duplicated(subset=['id']).sum()}")
# Out:
# --- Checking for Duplicate Keys ---
# movies_metadata 'id' duplicates: 30
# links 'movieId' duplicates: 0
# links 'tmdbId' duplicates: 248
# links_small 'movieId' duplicates: 0
# links_small 'tmdbId' duplicates: 12
# ratings duplicates: 0
# ratings_small duplicates: 0
# credits duplicates: 44
# keywords duplicates: 987

# %%
credits = credits.drop_duplicates()
print(f"credits: {credits.duplicated().sum()}")
credits = credits.drop_duplicates(subset=['id'])
print(f"credits duplicates: {credits.duplicated(subset=['id']).sum()}")
# Out:
# credits: 0
# credits duplicates: 0

# %%
keywords = keywords.drop_duplicates()
print(f"keywords: {keywords.duplicated().sum()}")
print(f"keywords duplicates: {keywords.duplicated(subset=['id']).sum()}")
# Out:
# keywords: 0
# keywords duplicates: 0

# %%
movies_metadata = movies_metadata.drop_duplicates(subset=['id'])
print(f"movies_metadata: {movies_metadata.duplicated().sum()}")
print(f"movies_metadata duplicates: {movies_metadata.duplicated(subset=['id']).sum()}")
# Out:
# movies_metadata: 0
# movies_metadata duplicates: 0

# %%
links = links.drop_duplicates(subset=['tmdbId'])
print(f"links: {links.duplicated().sum()}")
print(f"links duplicates: {links.duplicated(subset=['tmdbId']).sum()}")
# Out:
# links: 0
# links duplicates: 0

# %%
links_small  = links_small .drop_duplicates(subset=['tmdbId'])
print(f"links_small : {links_small .duplicated().sum()}")
print(f"links_small  duplicates: {links_small .duplicated(subset=['tmdbId']).sum()}")
# Out:
# links_small : 0
# links_small  duplicates: 0

# %%
all_ratings = pd.concat([ratings, ratings_small])

# %%
all_ratings.shape
# Out:
# (26124293, 4)

# %%
all_links = pd.concat([links,links_small])

# %%
all_links.shape
# Out:
# (54708, 3)

# %%
all_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
credits_keywords = credits.merge(keywords, on ='id')

# %%
credits_keywords.shape
# Out:
# (45432, 4)

# %%
credits_keywords.head(100)
# Out:
#                                                  cast  \
# 0   [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2   [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4   [{'cast_id': 1, 'character': 'George Banks', '...
# ..                                                ...
# 95  [{'cast_id': 2, 'character': 'Vinz', 'credit_i...
# 96  [{'cast_id': 1, 'character': 'Jo', 'credit_id'...
# 97  [{'cast_id': 2, 'character': 'Narrator', 'cred...
# 98  [{'cast_id': 1, 'character': 'Mayor John Pappa...
# 99  [{'cast_id': 1, 'character': 'Anthony Adams', ...
#
#                                                  crew     id  \
# 0   [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1   [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2   [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3   [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4   [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
# ..                                                ...    ...
# 95  [{'credit_id': '52fe423fc3a36847f800f88b', 'de...    406
# 96  [{'credit_id': '52fe46c8c3a36847f8111c21', 'de...  45549
# 97  [{'credit_id': '52fe469ac3a368484e099bcb', 'de...  63076
# 98  [{'credit_id': '571fb8ccc3a368775b0032ff', 'de...  11062
# 99  [{'credit_id': '52fe458b9251416c7505a35b', 'de...  13685
#
#                                              keywords
# 0   [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2   [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4   [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ..                                                ...
# 95  [{'id': 90, 'name': 'paris'}, {'id': 376, 'nam...
# 96                                                 []
# 97  [{'id': 2398, 'name': 'narration'}, {'id': 123...
# 98  [{'id': 417, 'name': 'corruption'}, {'id': 156...
# 99  [{'id': 380, 'name': 'brother brother relation...
#
# [100 rows x 4 columns]

# %%
movies_metadata['id'] = pd.to_numeric(movies_metadata['id'], errors='coerce')

# 2. Now, convert from float64 to Int64 (which allows <NA>)
movies_metadata['id'] = movies_metadata['id'].astype('Int64')

# %%
movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45436 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45436 non-null  object
#  3   genres                 45436 non-null  object
#  4   homepage               7777 non-null   object
#  5   id                     45433 non-null  Int64
#  6   imdb_id                45419 non-null  object
#  7   original_language      45425 non-null  object
#  8   original_title         45436 non-null  object
#  9   overview               44482 non-null  object
#  10  popularity             45431 non-null  object
#  11  poster_path            45050 non-null  object
#  12  production_companies   45433 non-null  object
#  13  production_countries   45433 non-null  object
#  14  release_date           45349 non-null  object
#  15  revenue                45430 non-null  float64
#  16  runtime                45173 non-null  float64
#  17  spoken_languages       45430 non-null  object
#  18  status                 45349 non-null  object
#  19  tagline                20401 non-null  object
#  20  title                  45430 non-null  object
#  21  video                  45430 non-null  object
#  22  vote_average           45430 non-null  float64
#  23  vote_count             45430 non-null  float64
# dtypes: Int64(1), float64(4), object(19)
# memory usage: 8.7+ MB

# %%
movies_metadata.shape
# Out:
# (45436, 24)

# %%
movies = movies_metadata.merge(credits_keywords,on='id')

# %%
movies.shape
# Out:
# (45432, 27)

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
# [5 rows x 27 columns]

# %%
movies = movies.drop_duplicates()
print(f"movies: {movies.duplicated().sum()}")
movies = movies.drop_duplicates(subset=['id'])
print(f"movies duplicates: {movies.duplicated(subset=['id']).sum()}")
# Out:
# movies: 0
# movies duplicates: 0

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
# [5 rows x 27 columns]

# %%
movies.shape
# Out:
# (45432, 27)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45432 entries, 0 to 45431
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45432 non-null  object
#  1   belongs_to_collection  4488 non-null   object
#  2   budget                 45432 non-null  object
#  3   genres                 45432 non-null  object
#  4   homepage               7774 non-null   object
#  5   id                     45432 non-null  Int64
#  6   imdb_id                45415 non-null  object
#  7   original_language      45421 non-null  object
#  8   original_title         45432 non-null  object
#  9   overview               44478 non-null  object
#  10  popularity             45429 non-null  object
#  11  poster_path            45046 non-null  object
#  12  production_companies   45429 non-null  object
#  13  production_countries   45429 non-null  object
#  14  release_date           45345 non-null  object
#  15  revenue                45429 non-null  float64
#  16  runtime                45172 non-null  float64
#  17  spoken_languages       45429 non-null  object
#  18  status                 45348 non-null  object
#  19  tagline                20401 non-null  object
#  20  title                  45429 non-null  object
#  21  video                  45429 non-null  object
#  22  vote_average           45429 non-null  float64
#  23  vote_count             45429 non-null  float64
#  24  cast                   45432 non-null  object
#  25  crew                   45432 non-null  object
#  26  keywords               45432 non-null  object
# dtypes: Int64(1), float64(4), object(22)
# memory usage: 9.4+ MB

# %%
movies = movies.merge(all_links,left_on='id',right_on='tmdbId')

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2  False                                                NaN  65000000
# 3  False                                                NaN  65000000
# 4  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1  http://toystory.disney.com/toy-story    862  tt0114709                en
# 2                                   NaN   8844  tt0113497                en
# 3                                   NaN   8844  tt0113497                en
# 4                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 2           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 3           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 4  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#               title  video vote_average vote_count  \
# 0         Toy Story  False          7.7     5415.0
# 1         Toy Story  False          7.7     5415.0
# 2           Jumanji  False          6.9     2413.0
# 3           Jumanji  False          6.9     2413.0
# 4  Grumpier Old Men  False          6.5       92.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 2  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 3  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 4  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 2  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 3  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 4  [{'credit_id': '52fe466a9251416c75077a89', 'de...
#
#                                             keywords movieId  imdbId   tmdbId
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...       1  114709    862.0
# 1  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...       1  114709    862.0
# 2  [{'id': 10090, 'name': 'board game'}, {'id': 1...       2  113497   8844.0
# 3  [{'id': 10090, 'name': 'board game'}, {'id': 1...       2  113497   8844.0
# 4  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...       3  113228  15602.0
#
# [5 rows x 30 columns]

# %%
movies = movies.drop_duplicates()
print(f"movies: {movies.duplicated().sum()}")
movies = movies.drop_duplicates(subset=['id'])
print(f"movies duplicates: {movies.duplicated(subset=['id']).sum()}")
# Out:
# movies: 0
# movies duplicates: 0

# %%
movies.shape
# Out:
# (45432, 30)

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2  False                                                NaN  65000000
# 4  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 6  False                                                NaN  16000000
# 8  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 8                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 2                                   NaN   8844  tt0113497                en
# 4                                   NaN  15602  tt0113228                en
# 6                                   NaN  31357  tt0114885                en
# 8                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 2                      Jumanji
# 4             Grumpier Old Men
# 6            Waiting to Exhale
# 8  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 2  When siblings Judy and Peter discover an encha...  ...
# 4  A family wedding reignites the ancient feud be...  ...
# 6  Cheated on, mistreated and stepped on, the wom...  ...
# 8  Just when George Banks has recovered from his ...  ...
#
#                          title  video vote_average vote_count  \
# 0                    Toy Story  False          7.7     5415.0
# 2                      Jumanji  False          6.9     2413.0
# 4             Grumpier Old Men  False          6.5       92.0
# 6            Waiting to Exhale  False          6.1       34.0
# 8  Father of the Bride Part II  False          5.7      173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 2  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 4  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 6  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 8  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 2  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 4  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 6  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 8  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords movieId  imdbId   tmdbId
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...       1  114709    862.0
# 2  [{'id': 10090, 'name': 'board game'}, {'id': 1...       2  113497   8844.0
# 4  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...       3  113228  15602.0
# 6  [{'id': 818, 'name': 'based on novel'}, {'id':...       4  114885  31357.0
# 8  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...       5  113041  11862.0
#
# [5 rows x 30 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45432 entries, 0 to 54513
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45432 non-null  object
#  1   belongs_to_collection  4488 non-null   object
#  2   budget                 45432 non-null  object
#  3   genres                 45432 non-null  object
#  4   homepage               7774 non-null   object
#  5   id                     45432 non-null  Int64
#  6   imdb_id                45415 non-null  object
#  7   original_language      45421 non-null  object
#  8   original_title         45432 non-null  object
#  9   overview               44478 non-null  object
#  10  popularity             45429 non-null  object
#  11  poster_path            45046 non-null  object
#  12  production_companies   45429 non-null  object
#  13  production_countries   45429 non-null  object
#  14  release_date           45345 non-null  object
#  15  revenue                45429 non-null  float64
#  16  runtime                45172 non-null  float64
#  17  spoken_languages       45429 non-null  object
#  18  status                 45348 non-null  object
#  19  tagline                20401 non-null  object
#  20  title                  45429 non-null  object
#  21  video                  45429 non-null  object
#  22  vote_average           45429 non-null  float64
#  23  vote_count             45429 non-null  float64
#  24  cast                   45432 non-null  object
#  25  crew                   45432 non-null  object
#  26  keywords               45432 non-null  object
#  27  movieId                45432 non-null  int64
#  28  imdbId                 45432 non-null  int64
#  29  tmdbId                 45432 non-null  float64
# dtypes: Int64(1), float64(5), int64(2), object(22)
# memory usage: 10.8+ MB

# %%
movies = movies.drop(['belongs_to_collection', 'homepage', 'imdb_id','original_title','original_language','poster_path','production_countries','spoken_languages','status','tagline','video','vote_average','tmdbId','imdbId'], axis=1)

# %%
movies.head()
# Out:
#    adult    budget                                             genres     id  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 2  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 4  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 6  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 8  False         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 2  When siblings Judy and Peter discover an encha...  17.015539
# 4  A family wedding reignites the ancient feud be...    11.7129
# 6  Cheated on, mistreated and stepped on, the wom...   3.859495
# 8  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies release_date  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 2  [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 4  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 6  [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# 8  [{'name': 'Sandollar Productions', 'id': 5842}...   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 2  262797249.0    104.0                      Jumanji      2413.0
# 4          0.0    101.0             Grumpier Old Men        92.0
# 6   81452156.0    127.0            Waiting to Exhale        34.0
# 8   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 2  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 4  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 6  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 8  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 2  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 4  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 6  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 8  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords  movieId
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...        1
# 2  [{'id': 10090, 'name': 'board game'}, {'id': 1...        2
# 4  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...        3
# 6  [{'id': 818, 'name': 'based on novel'}, {'id':...        4
# 8  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...        5

# %%
movies.shape
# Out:
# (45432, 16)

# %%
(movies.isna().sum() / len(movies)) * 100
# Out:
# adult                   0.000000
# budget                  0.000000
# genres                  0.000000
# id                      0.000000
# overview                2.099842
# popularity              0.006603
# production_companies    0.006603
# release_date            0.191495
# revenue                 0.006603
# runtime                 0.572284
# title                   0.006603
# vote_count              0.006603
# cast                    0.000000
# crew                    0.000000
# keywords                0.000000
# movieId                 0.000000
# dtype: float64

# %%
len(movies[['overview','popularity','production_companies','release_date','revenue','title','vote_count']].dropna())/len(movies)
# Out:
# 0.977372776897341

# %%
null_counts = movies.isna().sum()
cols_with_nulls = null_counts[null_counts > 0].index.tolist()

print(f"Columns with nulls: {cols_with_nulls}")

movies_cleaned = movies.dropna(subset=cols_with_nulls)

print(f"Original shape: {movies.shape}")
print(f"New shape: {movies_cleaned.shape}")
# Out:
# Columns with nulls: ['overview', 'popularity', 'production_companies', 'release_date', 'revenue', 'runtime', 'title', 'vote_count']
# Original shape: (45432, 16)
# New shape: (44404, 16)

# %%
movies = movies_cleaned
movies.shape
# Out:
# (44404, 16)

# %%
movies.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# overview                0
# popularity              0
# production_companies    0
# release_date            0
# revenue                 0
# runtime                 0
# title                   0
# vote_count              0
# cast                    0
# crew                    0
# keywords                0
# movieId                 0
# dtype: int64

# %%
import ast

def extract_names(text_list):
    try:
        data_list = ast.literal_eval(text_list)
        names = [item['name'] for item in data_list]
        return names
    
    except (ValueError, SyntaxError, TypeError):
        return []



movies['genres'] = movies['genres'].apply(extract_names)
movies['production_companies'] = movies['production_companies'].apply(extract_names)
movies['keywords'] = movies['keywords'].apply(extract_names)
movies['cast'] = movies['cast'].apply(extract_names)
movies['crew'] = movies['crew'].apply(extract_names)

# %%
movies.head(5)
# Out:
#    adult    budget                        genres     id  \
# 0  False  30000000   [Animation, Comedy, Family]    862
# 2  False  65000000  [Adventure, Fantasy, Family]   8844
# 4  False         0             [Romance, Comedy]  15602
# 6  False  16000000      [Comedy, Drama, Romance]  31357
# 8  False         0                      [Comedy]  11862
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 2  When siblings Judy and Peter discover an encha...  17.015539
# 4  A family wedding reignites the ancient feud be...    11.7129
# 6  Cheated on, mistreated and stepped on, the wom...   3.859495
# 8  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies release_date  \
# 0                          [Pixar Animation Studios]   1995-10-30
# 2  [TriStar Pictures, Teitler Film, Interscope Co...   1995-12-15
# 4                     [Warner Bros., Lancaster Gate]   1995-12-22
# 6           [Twentieth Century Fox Film Corporation]   1995-12-22
# 8       [Sandollar Productions, Touchstone Pictures]   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 2  262797249.0    104.0                      Jumanji      2413.0
# 4          0.0    101.0             Grumpier Old Men        92.0
# 6   81452156.0    127.0            Waiting to Exhale        34.0
# 8   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 2  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 4  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 6  [Whitney Houston, Angela Bassett, Loretta Devi...
# 8  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                                 crew  \
# 0  [John Lasseter, Joss Whedon, Andrew Stanton, J...
# 2  [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 4  [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 6  [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 8  [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
#
#                                             keywords  movieId
# 0  [jealousy, toy, boy, friendship, friends, riva...        1
# 2  [board game, disappearance, based on children'...        2
# 4  [fishing, best friend, duringcreditsstinger, o...        3
# 6  [based on novel, interracial relationship, sin...        4
# 8  [baby, midlife crisis, confidence, aging, daug...        5

# %%
movies = movies.reset_index(drop=True)
movies.head(5)
# Out:
#    adult    budget                        genres     id  \
# 0  False  30000000   [Animation, Comedy, Family]    862
# 1  False  65000000  [Adventure, Fantasy, Family]   8844
# 2  False         0             [Romance, Comedy]  15602
# 3  False  16000000      [Comedy, Drama, Romance]  31357
# 4  False         0                      [Comedy]  11862
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies release_date  \
# 0                          [Pixar Animation Studios]   1995-10-30
# 1  [TriStar Pictures, Teitler Film, Interscope Co...   1995-12-15
# 2                     [Warner Bros., Lancaster Gate]   1995-12-22
# 3           [Twentieth Century Fox Film Corporation]   1995-12-22
# 4       [Sandollar Productions, Touchstone Pictures]   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 1  262797249.0    104.0                      Jumanji      2413.0
# 2          0.0    101.0             Grumpier Old Men        92.0
# 3   81452156.0    127.0            Waiting to Exhale        34.0
# 4   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                                 crew  \
# 0  [John Lasseter, Joss Whedon, Andrew Stanton, J...
# 1  [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2  [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3  [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4  [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
#
#                                             keywords  movieId
# 0  [jealousy, toy, boy, friendship, friends, riva...        1
# 1  [board game, disappearance, based on children'...        2
# 2  [fishing, best friend, duringcreditsstinger, o...        3
# 3  [based on novel, interracial relationship, sin...        4
# 4  [baby, midlife crisis, confidence, aging, daug...        5

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies.head(5)
# Out:
#    adult    budget                        genres     id  \
# 0  False  30000000   [Animation, Comedy, Family]    862
# 1  False  65000000  [Adventure, Fantasy, Family]   8844
# 2  False         0             [Romance, Comedy]  15602
# 3  False  16000000      [Comedy, Drama, Romance]  31357
# 4  False         0                      [Comedy]  11862
#
#                                             overview popularity  \
# 0  [Led, by, Woody,, Andy's, toys, live, happily,...  21.946943
# 1  [When, siblings, Judy, and, Peter, discover, a...  17.015539
# 2  [A, family, wedding, reignites, the, ancient, ...    11.7129
# 3  [Cheated, on,, mistreated, and, stepped, on,, ...   3.859495
# 4  [Just, when, George, Banks, has, recovered, fr...   8.387519
#
#                                 production_companies release_date  \
# 0                          [Pixar Animation Studios]   1995-10-30
# 1  [TriStar Pictures, Teitler Film, Interscope Co...   1995-12-15
# 2                     [Warner Bros., Lancaster Gate]   1995-12-22
# 3           [Twentieth Century Fox Film Corporation]   1995-12-22
# 4       [Sandollar Productions, Touchstone Pictures]   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 1  262797249.0    104.0                      Jumanji      2413.0
# 2          0.0    101.0             Grumpier Old Men        92.0
# 3   81452156.0    127.0            Waiting to Exhale        34.0
# 4   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                                 crew  \
# 0  [John Lasseter, Joss Whedon, Andrew Stanton, J...
# 1  [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2  [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3  [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4  [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
#
#                                             keywords  movieId
# 0  [jealousy, toy, boy, friendship, friends, riva...        1
# 1  [board game, disappearance, based on children'...        2
# 2  [fishing, best friend, duringcreditsstinger, o...        3
# 3  [based on novel, interracial relationship, sin...        4
# 4  [baby, midlife crisis, confidence, aging, daug...        5

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['overview'] = movies['overview'].apply(lambda x:[i.replace(" ","") for i in x])
movies['production_companies'] = movies['production_companies'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head(5)
# Out:
#    adult    budget                        genres     id  \
# 0  False  30000000   [Animation, Comedy, Family]    862
# 1  False  65000000  [Adventure, Fantasy, Family]   8844
# 2  False         0             [Romance, Comedy]  15602
# 3  False  16000000      [Comedy, Drama, Romance]  31357
# 4  False         0                      [Comedy]  11862
#
#                                             overview popularity  \
# 0  [Led, by, Woody,, Andy's, toys, live, happily,...  21.946943
# 1  [When, siblings, Judy, and, Peter, discover, a...  17.015539
# 2  [A, family, wedding, reignites, the, ancient, ...    11.7129
# 3  [Cheated, on,, mistreated, and, stepped, on,, ...   3.859495
# 4  [Just, when, George, Banks, has, recovered, fr...   8.387519
#
#                                 production_companies release_date  \
# 0                            [PixarAnimationStudios]   1995-10-30
# 1  [TriStarPictures, TeitlerFilm, InterscopeCommu...   1995-12-15
# 2                       [WarnerBros., LancasterGate]   1995-12-22
# 3               [TwentiethCenturyFoxFilmCorporation]   1995-12-22
# 4         [SandollarProductions, TouchstonePictures]   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 1  262797249.0    104.0                      Jumanji      2413.0
# 2          0.0    101.0             Grumpier Old Men        92.0
# 3   81452156.0    127.0            Waiting to Exhale        34.0
# 4   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2  [WalterMatthau, JackLemmon, Ann-Margret, Sophi...
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine,...
# 4  [SteveMartin, DianeKeaton, MartinShort, Kimber...
#
#                                                 crew  \
# 0  [JohnLasseter, JossWhedon, AndrewStanton, Joel...
# 1  [LarryJ.Franco, JonathanHensleigh, JamesHorner...
# 2  [HowardDeutch, MarkStevenJohnson, MarkStevenJo...
# 3  [ForestWhitaker, RonaldBass, RonaldBass, EzraS...
# 4  [AlanSilvestri, ElliotDavis, NancyMeyers, Nanc...
#
#                                             keywords  movieId
# 0  [jealousy, toy, boy, friendship, friends, riva...        1
# 1  [boardgame, disappearance, basedonchildren'sbo...        2
# 2  [fishing, bestfriend, duringcreditsstinger, ol...        3
# 3  [basedonnovel, interracialrelationship, single...        4
# 4  [baby, midlifecrisis, confidence, aging, daugh...        5

# %%
movies['tags'] = movies['genres'] + movies['overview'] + movies['production_companies'] + movies['cast'] + movies['crew'] + movies['keywords']

# %%
movies.head(5)
# Out:
#    adult    budget                        genres     id  \
# 0  False  30000000   [Animation, Comedy, Family]    862
# 1  False  65000000  [Adventure, Fantasy, Family]   8844
# 2  False         0             [Romance, Comedy]  15602
# 3  False  16000000      [Comedy, Drama, Romance]  31357
# 4  False         0                      [Comedy]  11862
#
#                                             overview popularity  \
# 0  [Led, by, Woody,, Andy's, toys, live, happily,...  21.946943
# 1  [When, siblings, Judy, and, Peter, discover, a...  17.015539
# 2  [A, family, wedding, reignites, the, ancient, ...    11.7129
# 3  [Cheated, on,, mistreated, and, stepped, on,, ...   3.859495
# 4  [Just, when, George, Banks, has, recovered, fr...   8.387519
#
#                                 production_companies release_date  \
# 0                            [PixarAnimationStudios]   1995-10-30
# 1  [TriStarPictures, TeitlerFilm, InterscopeCommu...   1995-12-15
# 2                       [WarnerBros., LancasterGate]   1995-12-22
# 3               [TwentiethCenturyFoxFilmCorporation]   1995-12-22
# 4         [SandollarProductions, TouchstonePictures]   1995-02-10
#
#        revenue  runtime                        title  vote_count  \
# 0  373554033.0     81.0                    Toy Story      5415.0
# 1  262797249.0    104.0                      Jumanji      2413.0
# 2          0.0    101.0             Grumpier Old Men        92.0
# 3   81452156.0    127.0            Waiting to Exhale        34.0
# 4   76578911.0    106.0  Father of the Bride Part II       173.0
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2  [WalterMatthau, JackLemmon, Ann-Margret, Sophi...
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine,...
# 4  [SteveMartin, DianeKeaton, MartinShort, Kimber...
#
#                                                 crew  \
# 0  [JohnLasseter, JossWhedon, AndrewStanton, Joel...
# 1  [LarryJ.Franco, JonathanHensleigh, JamesHorner...
# 2  [HowardDeutch, MarkStevenJohnson, MarkStevenJo...
# 3  [ForestWhitaker, RonaldBass, RonaldBass, EzraS...
# 4  [AlanSilvestri, ElliotDavis, NancyMeyers, Nanc...
#
#                                             keywords  movieId  \
# 0  [jealousy, toy, boy, friendship, friends, riva...        1
# 1  [boardgame, disappearance, basedonchildren'sbo...        2
# 2  [fishing, bestfriend, duringcreditsstinger, ol...        3
# 3  [basedonnovel, interracialrelationship, single...        4
# 4  [baby, midlifecrisis, confidence, aging, daugh...        5
#
#                                                 tags
# 0  [Animation, Comedy, Family, Led, by, Woody,, A...
# 1  [Adventure, Fantasy, Family, When, siblings, J...
# 2  [Romance, Comedy, A, family, wedding, reignite...
# 3  [Comedy, Drama, Romance, Cheated, on,, mistrea...
# 4  [Comedy, Just, when, George, Banks, has, recov...

# %%
movies['tags'] = movies['tags'].apply(lambda x:" ".join(x))

# %%
movies['tags'] = movies['tags'].apply(lambda x:x.lower())

# %%
# The list of columns you want to make sure are gone
columns_to_drop = ['genres', 'overview', 'production_companies', 'cast', 'crew', 'keywords']

# Use errors='ignore' to prevent the error
movies = movies.drop(columns_to_drop, axis=1, errors='ignore')

# %%
movies.head()
# Out:
#    adult    budget     id popularity release_date      revenue  runtime  \
# 0  False  30000000    862  21.946943   1995-10-30  373554033.0     81.0
# 1  False  65000000   8844  17.015539   1995-12-15  262797249.0    104.0
# 2  False         0  15602    11.7129   1995-12-22          0.0    101.0
# 3  False  16000000  31357   3.859495   1995-12-22   81452156.0    127.0
# 4  False         0  11862   8.387519   1995-02-10   76578911.0    106.0
#
#                          title  vote_count  movieId  \
# 0                    Toy Story      5415.0        1
# 1                      Jumanji      2413.0        2
# 2             Grumpier Old Men        92.0        3
# 3            Waiting to Exhale        34.0        4
# 4  Father of the Bride Part II       173.0        5
#
#                                                 tags
# 0  animation comedy family led by woody, andy's t...
# 1  adventure fantasy family when siblings judy an...
# 2  romance comedy a family wedding reignites the ...
# 3  comedy drama romance cheated on, mistreated an...
# 4  comedy just when george banks has recovered fr...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44404 entries, 0 to 44403
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   adult         44404 non-null  object
#  1   budget        44404 non-null  object
#  2   id            44404 non-null  Int64
#  3   popularity    44404 non-null  object
#  4   release_date  44404 non-null  object
#  5   revenue       44404 non-null  float64
#  6   runtime       44404 non-null  float64
#  7   title         44404 non-null  object
#  8   vote_count    44404 non-null  float64
#  9   movieId       44404 non-null  int64
#  10  tags          44404 non-null  object
# dtypes: Int64(1), float64(3), int64(1), object(6)
# memory usage: 3.8+ MB

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words = 'english')

# %%
vectors = cv.fit_transform(movies['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
list(cv.get_feature_names_out())
# Out:
# ['000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1920s',
#  '1930s',
#  '1940s',
#  '1944',
#  '1945',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970',
#  '1970s',
#  '1980',
#  '1980s',
#  '1990s',
#  '1999',
#  '19th',
#  '19thcentury',
#  '20',
#  '200',
#  '2000',
#  '2004',
#  '2005',
#  '2006',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '35',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '60s',
#  '70',
#  '70s',
#  '80',
#  '80s',
#  'aaron',
#  'abandoned',
#  'abandons',
#  'abducted',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'abortion',
#  'abroad',
#  'absence',
#  'absurd',
#  'abuse',
#  'abused',
#  'abusive',
#  'academy',
#  'accept',
#  'accepted',
#  'accepts',
#  'access',
#  'accident',
#  'accidental',
#  'accidentally',
#  'acclaimed',
#  'accompanied',
#  'according',
#  'account',
#  'accused',
#  'ace',
#  'achieve',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activist',
#  'activists',
#  'activities',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adams',
#  'adamsandler',
#  'adaptation',
#  'adapted',
#  'addict',
#  'addicted',
#  'addiction',
#  'addition',
#  'adolescence',
#  'adolescent',
#  'adopt',
#  'adopted',
#  'adoption',
#  'adrian',
#  'adult',
#  'adultery',
#  'adulthood',
#  'adults',
#  'advantage',
#  'adventure',
#  'adventures',
#  'advertising',
#  'advice',
#  'affair',
#  'affairs',
#  'affected',
#  'affection',
#  'affections',
#  'afghanistan',
#  'afraid',
#  'africa',
#  'african',
#  'aftercreditsstinger',
#  'aftermath',
#  'age',
#  'aged',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggressive',
#  'aging',
#  'ago',
#  'agostino',
#  'agree',
#  'agrees',
#  'ah',
#  'ahead',
#  'aid',
#  'aided',
#  'aids',
#  'aip',
#  'air',
#  'aires',
#  'airplane',
#  'airport',
#  'ajay',
#  'aka',
#  'akikaurismäki',
#  'akirakurosawa',
#  'al',
#  'alan',
#  'alanarkin',
#  'alanhale',
#  'alansilvestri',
#  'alaska',
#  'albert',
#  'alberts',
#  'album',
#  'alcohol',
#  'alcoholic',
#  'alcoholism',
#  'alecbaldwin',
#  'alex',
#  'alexander',
#  'alexandergolitzen',
#  'alexandredesplat',
#  'alfredhitchcock',
#  'alfredmolina',
#  'alfrednewman',
#  'ali',
#  'alice',
#  'alien',
#  'alieninvasion',
#  'aliens',
#  'alike',
#  'alive',
#  'allen',
#  'alliance',
#  'allied',
#  'allies',
#  'allow',
#  'allowed',
#  'allows',
#  'alongside',
#  'alter',
#  'alternative',
#  'amanda',
#  'amateur',
#  'amato',
#  'amazing',
#  'amazon',
#  'ambassador',
#  'ambition',
#  'ambitious',
#  'amblinentertainment',
#  'ambush',
#  'america',
#  'american',
#  'americanfootball',
#  'americaninternationalpictures',
#  'americans',
#  'amico',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amsterdam',
#  'amy',
#  'ana',
#  'ancient',
#  'anderson',
#  'andrea',
#  'andrew',
#  'andrews',
#  'android',
#  'andy',
#  'andygarcía',
#  'angel',
#  'angela',
#  'angeles',
#  'angelo',
#  'angels',
#  'anger',
#  'angry',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'anime',
#  'anjelicahuston',
#  'ann',
#  'anna',
#  'anne',
#  'annie',
#  'anniversary',
#  'announces',
#  'annual',
#  'anonymous',
#  'answer',
#  'answers',
#  'anthology',
#  'anthony',
#  'anthonyhopkins',
#  'anthonyquinn',
#  'anti',
#  'antics',
#  'antoine',
#  'antonio',
#  'antoniobanderas',
#  'apache',
#  'apart',
#  'apartment',
#  'apocalypse',
#  'apocalyptic',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appears',
#  'apple',
#  'appointed',
#  'apprentice',
#  'approach',
#  'approaches',
#  'april',
#  'arab',
#  'archaeologist',
#  'architect',
#  'archival',
#  'archive',
#  'arctic',
#  'arcy',
#  'area',
#  'aren',
#  'argentina',
#  'arise',
#  'aristocrat',
#  'arizona',
#  'arm',
#  'armed',
#  'arms',
#  'armstrong',
#  'army',
#  'arnold',
#  'arnonmilchan',
#  'arranged',
#  'arranges',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogant',
#  'art',
#  'arte',
#  'artefrancecinéma',
#  'arthur',
#  'artist',
#  'artistic',
#  'artists',
#  'arts',
#  'asia',
#  'asian',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'aspiring',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assault',
#  'assigned',
#  'assignment',
#  'assistant',
#  'assumes',
#  'astronaut',
#  'asylum',
#  'athlete',
#  'atmosphere',
#  'atomic',
#  'attack',
#  'attacked',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attend',
#  'attention',
#  'attitude',
#  'attorney',
#  'attracted',
#  'attraction',
#  'attractive',
#  'audience',
#  'audiences',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'austrian',
#  'author',
#  'authorities',
#  'authority',
#  'auto',
#  'available',
#  'avenge',
#  'average',
#  'avilerner',
#  'avoid',
#  'avykaufman',
#  'awaits',
#  'awakens',
#  'award',
#  'aware',
#  'away',
#  'awkward',
#  'awry',
#  'baby',
#  'babysitter',
#  'bachelor',
#  'backdrop',
#  'background',
#  'bad',
#  'badly',
#  'bag',
#  'bailey',
#  'baker',
#  'balance',
#  'ball',
#  'ballet',
#  'band',
#  'bandit',
#  'bandits',
#  'bands',
#  'bank',
#  'banker',
#  'bankrobbery',
#  'banks',
#  'bar',
#  'barbara',
#  'barbarastanwyck',
#  'barbie',
#  'barely',
#  'bargained',
#  'baron',
#  'barry',
#  'barrylevinson',
#  'bars',
#  'base',
#  'baseball',
#  'based',
#  'basedoncomic',
#  'basedonnovel',
#  'basedonplayormusical',
#  'basedontruestory',
#  'basedontvseries',
#  'basedonvideogame',
#  'basedonyoungadultnovel',
#  'basement',
#  'basketball',
#  'batman',
#  'battle',
#  'battles',
#  'battling',
#  'bay',
#  'bbc',
#  'bbcfilms',
#  'beach',
#  'bear',
#  'bears',
#  'beast',
#  'beat',
#  'beaten',
#  'beating',
#  'beautiful',
#  'beauty',
#  'bed',
#  'beer',
#  'befriended',
#  'befriends',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behavior',
#  'beings',
#  'belief',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'bell',
#  'belle',
#  'belongs',
#  'beloved',
#  'ben',
#  'benaffleck',
#  'beneath',
#  'benhecht',
#  'benjamin',
#  'benkingsley',
#  'bennett',
#  'bennye',
#  'benstiller',
#  'bent',
#  'berlin',
#  'berman',
#  'bernard',
#  'bessflowers',
#  'best',
#  'bestfriend',
#  'bet',
#  'beth',
#  'betrayal',
#  'betrayed',
#  'bettedavis',
#  'better',
#  'betty',
#  'beverly',
#  'bible',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'biker',
#  'bikini',
#  'billion',
#  'billionaire',
#  'billmurray',
#  'billnighy',
#  'billpaxton',
#  'billpullman',
#  'billy',
#  'billybobthornton',
#  'billyhopkins',
#  'billywilder',
#  'billyzane',
#  'bing',
#  'biography',
#  'biological',
#  'bird',
#  'birth',
#  'birthday',
#  'bishop',
#  'bit',
#  'bitter',
#  'bizarre',
#  'black',
#  'blackmail',
#  'blake',
#  'blakeedwards',
#  'blame',
#  'blaxploitation',
#  'blind',
#  'block',
#  'blonde',
#  'blood',
#  'bloody',
#  'blow',
#  'blue',
#  'blues',
#  'bmovie',
#  'bo',
#  'board',
#  'boarding',
#  'boardingschool',
#  'boat',
#  'boazdavidson',
#  'bob',
#  'bobby',
#  'bobweinstein',
#  'bodies',
#  'body',
#  'bodyguard',
#  'bold',
#  'bollywood',
#  'bomb',
#  'bombing',
#  'bond',
#  'bonds',
#  'bonnietimmermann',
#  'book',
#  'books',
#  'border',
#  'bored',
#  'boring',
#  'boriskarloff',
#  'born',
#  'boss',
#  'boston',
#  'bound',
#  'boundaries',
#  'bounty',
#  'bourgeois',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'boyd',
#  'boyfriend',
#  'boyle',
#  'boys',
#  'braddourif',
#  'bradpitt',
#  'brain',
#  'brand',
#  'brave',
#  'brazil',
#  'brazilian',
#  'break',
#  'breakdown',
#  'breaking',
#  'breaks',
#  'brian',
#  'briancox',
#  'briangrazer',
#  'bride',
#  'bridge',
#  'brief',
#  'brien',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'britain',
#  'british',
#  'britishbroadcastingcorporation',
#  'broadcast',
#  'broadway',
#  'broke',
#  'broken',
#  'brooklyn',
#  'brooks',
#  'brothel',
#  'brother',
#  'brotherbrotherrelationship',
#  'brothers',
#  'brothersisterrelationship',
#  'brought',
#  'brown',
#  'bruce',
#  'brucecampbell',
#  'brucedavison',
#  'brucedern',
#  'brucewillis',
#  'bruno',
#  'brutal',
#  'brutality',
#  'brutally',
#  'bryan',
#  'buck',
#  'bud',
#  'buddies',
#  'buddy',
#  'budget',
#  'buenos',
#  'build',
#  'building',
#  'builds',
#  'built',
#  'bull',
#  'bullet',
#  'bully',
#  'bullying',
#  'bumbling',
#  'bunch',
#  'burglar',
#  'buried',
#  'burnett',
#  'burning',
#  'burns',
#  'burtlancaster',
#  'burton',
#  'burtreynolds',
#  'bus',
#  'bush',
#  'business',
#  'businessman',
#  'busterkeaton',
#  'busy',
#  'butcher',
#  'butler',
#  'buy',
#  'buys',
#  'byrne',
#  'cab',
#  'cabin',
#  'cafe',
#  'california',
#  'called',
#  'calling',
#  'calls',
#  'came',
#  'camera',
#  'cameras',
#  'cameron',
#  'camp',
#  'campaign',
#  'campbell',
#  'camping',
#  'campus',
#  'canada',
#  'canadian',
#  'canal',
#  'cancer',
#  'candiceelzinga',
#  'candidate',
#  'cannibal',
#  'canuxploitation',
#  'capable',
#  'capital',
#  'capitalism',
#  'captain',
#  'captive',
#  'capture',
#  'captured',
#  'captures',
#  'car',
#  'caraccident',
#  'carchase',
#  'carcrash',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'careers',
#  'carefree',
#  'cargo',
#  'caribbean',
#  'caring',
#  'carl',
#  'carlo',
#  'carlos',
#  'carmen',
#  'carnival',
#  'carol',
#  'carpenter',
#  'carrie',
#  'carries',
#  'carroll',
#  'carrolnaish',
#  'carry',
#  'carrying',
#  'cars',
#  'carter',
#  'carterburwell',
#  'cartoon',
#  'carygrant',
#  'case',
#  'cases',
#  'casey',
#  'cash',
#  'casino',
#  'cast',
#  'castle',
#  'castlerockentertainment',
#  'cat',
#  'catastrophe',
#  'catch',
#  'catches',
#  'catherine',
#  'catherinedeneuve',
#  'catholic',
#  'cattle',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cavalry',
#  'cave',
#  'cecilb',
#  'cedricgibbons',
#  'celebrate',
#  'celebrated',
#  'celebration',
#  'celebrity',
#  'cell',
#  'cemetery',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'centrenationaldelacinématographie',
#  'centuries',
#  'century',
#  'certain',
#  'chain',
#  'challenge',
#  'challenged',
#  'challenges',
#  'champion',
#  'championship',
#  'chan',
#  'chance',
#  'chang',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'channelfourfilms',
#  'chaos',
#  'chaotic',
#  'character',
#  'characters',
#  'charge',
#  'charged',
#  'charges',
#  'charismatic',
#  'charles',
#  'charlesb',
#  'charlesband',
#  'charlesbronson',
#  'charlesdurning',
#  'charlesh',
#  'charleslane',
#  'charleslang',
#  'charless',
#  'charlie',
#  'charliechaplin',
#  'charlotte',
#  'charltonheston',
#  'charm',
#  'charming',
#  'charms',
#  'chase',
#  'chased',
#  'chases',
#  'chasing',
#  'cheating',
#  'check',
#  'cheerleader',
#  'chef',
#  'chen',
#  'chess',
#  'cheung',
#  'chi',
#  'chicago',
#  'chicken',
#  'chief',
#  'child',
#  'childhood',
#  'children',
#  'chilling',
#  'china',
#  'chinese',
#  'ching',
#  'choice',
#  'choices',
#  'choose',
#  'chooses',
#  'chosen',
#  'chris',
#  'chriso',
#  'chrisrock',
#  'christ',
#  'christian',
#  'christianity',
#  'christianslater',
#  'christine',
#  'christmas',
#  'christophebeck',
#  'christopher',
#  'christopherdoyle',
#  'christopherlee',
#  'christopherlloyd',
#  'christophermcdonald',
#  'christopherplummer',
#  'christopherwalken',
#  'christopheryoung',
#  'chronicle',
#  'chronicles',
#  'chuck',
#  'chun',
#  'chung',
#  'church',
#  'cia',
#  'cinema',
#  'cinematic',
#  'ciné',
#  'cinécinéma',
#  'circle',
#  'circumstances',
#  'circus',
#  'cities',
#  'citizen',
#  'citizens',
#  'city',
#  'civil',
#  'civilization',
#  'cjentertainment',
#  'claim',
#  'claiming',
#  'claims',
#  'claire',
#  'clan',
#  'clark',
#  'clarke',
#  'clash',
#  'class',
#  'classes',
#  'classic',
#  'classmate',
#  'classmates',
#  'claude',
#  'claudechabrol',
#  'claudevandamme',
#  'claus',
#  'clay',
#  'clean',
#  'clear',
#  'clerk',
#  'clever',
#  'client',
#  'clients',
#  'climbing',
#  'cline',
#  'clinic',
#  'clinteastwood',
#  'clinthoward',
#  'clinton',
#  'clips',
#  'clock',
#  'clorisleachman',
#  'close',
#  'closed',
#  'closely',
#  'closer',
#  'closest',
#  'clothes',
#  'clown',
#  'club',
#  'clubs',
#  'clues',
#  'cnc',
#  'coach',
#  'coast',
#  'coastal',
#  'cobb',
#  'cocaine',
#  'code',
#  'coffee',
#  'coffin',
#  'cohen',
#  'cold',
#  'coldwar',
#  'cole',
#  'collapse',
#  'colleague',
#  'colleagues',
#  'collect',
#  'collection',
#  'colleencamp',
#  'college',
#  'collide',
#  'collins',
#  'colonel',
#  'colony',
#  'color',
#  'colorful',
#  'columbiapictures',
#  'columbiapicturescorporation',
#  'com',
#  'coma',
#  'combat',
#  'combination',
#  'come',
#  'comeback',
#  'comedian',
#  'comedic',
#  'comedy',
#  'comes',
#  'comfort',
#  'comic',
#  'comics',
#  'coming',
#  'comingofage',
#  'command',
#  'commander',
#  'commercial',
#  'commit',
#  'commitment',
#  'commits',
#  'committed',
#  'committing',
#  'common',
#  'communism',
#  'communist',
#  'community',
#  'companion',
#  'company',
#  'compelling',
#  'compete',
#  'competing',
#  'competition',
#  'complete',
#  'completely',
#  'complex',
#  'complicated',
#  'complications',
#  'composed',
#  'composer',
#  'computer',
#  'concerned',
#  'concerns',
#  'concert',
#  'conclusion',
#  'condition',
#  'conditions',
#  'confession',
#  'confidence',
#  'confident',
#  'conflict',
#  'conflicts',
#  'confront',
#  'confrontation',
#  'confronted',
#  'confronts',
#  'confused',
#  'confusion',
#  'conman',
#  'connect',
#  'connected',
#  'connection',
#  'connell',
#  'connor',
#  'conquer',
#  'conscience',
#  'consciousness',
#  'consequences',
#  'conservative',
#  'considered',
#  'consists',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'construction',
#  'contact',
#  'contains',
#  ...]

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))
    
    return " ".join(y)

# %%
movies['tags'] = movies['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
def recommend(movie_title):
    index = movies[movies['title'] == movie_title].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    
    for i in distances[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend('3 Idiots')
# Out:
# Kicking and Screaming
# Telling You
# Summer of 8
# Student of the Year
# Loser

# %%
movies['popularity'] = pd.to_numeric(movies['popularity'], errors='coerce')

# %%
def recommend_hybrid(movie_title, top_n=5):
    index = movies[movies['title'] == movie_title].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    similar_indices = [i[0] for i in distances[1:51]]
    similar_movies = movies.iloc[similar_indices]
    
    sorted_by_popularity = similar_movies.sort_values('popularity', ascending=False)
    
    for title in sorted_by_popularity['title'].head(top_n):
        print(title)

# %%
recommend_hybrid('Jumanji')
# Out:
# Nerve
# The Croods
# Wreck-It Ralph
# The Spiderwick Chronicles
# Brainscan
